# %%
import matplotlib.pyplot as plt
from tools import SRI_sum

mlrf1 = SRI_sum.main('mlrf1')
fwyf1 = SRI_sum.main('fwyf1')
sanf1 = SRI_sum.main('sanf1')
smkf1 = SRI_sum.main('smkf1')

print("mlrf1\n", mlrf1)
print("fwyf1\n", fwyf1)
print("sanf1\n", sanf1)
print("smkf1\n", smkf1)
# Out:
# mlrf1
#          SRI
# 1987    0.0
# 1988    0.0
# 1989   45.0
# 1990  183.0
# 1991  192.0
# 1992    9.0
# 1993  135.0
# 1994   12.0
# 1995   18.0
# 1996   18.0
# 1997   72.0
# 1998   81.0
# 1999   63.0
# 2000   60.0
# 2001   18.0
# 2002   33.0
# 2003   67.5
# 2004   99.0
# 2005   76.5
# 2006   69.0
# 2007  142.5
# 2008   18.0
# 2009  153.0
# 2010  114.0
# 2011   30.0
# 2012   42.0
# 2013    0.0
# 2014  150.0
# 2015  159.0
# 2016   36.0
# 2017   93.0
# fwyf1
#          SRI
# 1987    0.0
# 1988    0.0
# 1989   81.0
# 1990  222.0
# 1991   33.0
# 1992   18.0
# 1993  117.0
# 1994   57.0
# 1995   81.0
# 1996    6.0
# 1997  105.0
# 1998   72.0
# 1999   78.0
# 2000  108.0
# 2001   39.0
# 2002   21.0
# 2003   51.0
# 2004   87.0
# 2005   40.5
# 2006   75.0
# 2007   15.0
# 2008   24.0
# 2009  142.5
# 2010  108.0
# 2011  108.0
# 2012   27.0
# 2013    6.0
# 2014  111.0
# 2015  381.0
# 2016   48.0
# 2017  163.5
# sanf1
#          SRI
# 1987    0.0
# 1988    0.0
# 1989   81.0
# 1990  222.0
# 1991   58.5
# 1992    0.0
# 1993  192.0
# 1994   12.0
# 1995  108.0
# 1996   33.0
# 1997   70.5
# 1998   69.0
# 1999   54.0
# 2000   99.0
# 2001   27.0
# 2002   33.0
# 2003   66.0
# 2004  123.0
# 2005  147.0
# 2006    0.0
# 2007    0.0
# 2008    0.0
# 2009    0.0
# 2010    0.0
# 2011    0.0
# 2012    0.0
# 2013    0.0
# 2014    0.0
# 2015    0.0
# 2016    0.0
# 2017    0.0
# smkf1
#          SRI
# 1987    0.0
# 1988    9.0
# 1989   24.0
# 1990   81.0
# 1991    0.0
# 1992   15.0
# 1993   93.0
# 1994   42.0
# 1995  102.0
# 1996   57.0
# 1997   99.0
# 1998   78.0
# 1999   69.0
# 2000   72.0
# 2001   39.0
# 2002   78.0
# 2003   54.0
# 2004    0.0
# 2005   54.0
# 2006   78.0
# 2007  199.5
# 2008    0.0
# 2009    0.0
# 2010    0.0
# 2011    0.0
# 2012    0.0
# 2013    0.0
# 2014    0.0
# 2015    0.0
# 2016    0.0
# 2017    0.0

# %%
fig= plt.figure(figsize=(18, 12))

ax= fig.add_subplot(1, 1, 1)
ax.set_axisbelow(True)
ax.minorticks_on()
ax.grid(which='major', alpha=0.5, linestyle='-', linewidth='0.75', color='grey')
ax.grid(which='minor', alpha=0.5, linestyle='-', linewidth='0.25', color='grey')
ax.margins(x = 0.02 , y = 0.05)


plt.plot(mlrf1.index.values, mlrf1['SRI'].values, color='orange', label= 'mlrf1',
                  marker='P', markeredgewidth = 2, markeredgecolor='orange', 
                  markerfacecolor=(0, 0, 0, 0.01),markersize=15)
plt.plot(sanf1.index.values, sanf1['SRI'].values, color='red', label= 'sanf1',
                  marker='v', markeredgewidth = 2, markeredgecolor='red', 
                  markerfacecolor=(0, 0, 0, 0.01), markersize=12)
plt.plot(smkf1.index.values, smkf1['SRI'].values, color='green', label= 'smkf1',
                  marker='*', markeredgewidth = 2, markeredgecolor='green', 
                  markerfacecolor=(0, 0, 0, 0.01), markersize=18)
plt.plot(fwyf1.index.values, fwyf1['SRI'].values, color='blue', label= 'fwyf1',
                  marker='X', markeredgewidth = 2, markeredgecolor='blue', 
                  markerfacecolor=(0, 0, 0, 0.01), markersize=18)

#dont forget to add axis lables and possibly title

plt.legend(loc=2, prop={'size': 20})
plt.savefig("fig2test.png")
plt.show()
